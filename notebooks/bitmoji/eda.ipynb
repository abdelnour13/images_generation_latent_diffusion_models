# %% [markdown]
# ### Necessary Packages

# %%
import sys
import seaborn as sns
import warnings

# %%
sys.path.append('../..')

# %%
import definitions as D
from src.utils import get_metadata,diaply_random_images,get_metadata,seed_everything

# %%
warnings.filterwarnings("ignore",category=FutureWarning)
warnings.filterwarnings("ignore",category=UserWarning)

# %%
sns.set_theme(style="whitegrid", palette="Set2")

# %% [markdown]
# ### Reproducibility

# %%
SEED = 42
IMAGES_DIR = D.DATASETS['bitmojie'].images_dir

# %%
seed_everything(SEED)

# %% [markdown]
# ### Metadata

# %%
metadata = get_metadata(IMAGES_DIR)
# Out:
#   0%|          | 0/130227 [00:00<?, ?it/s]

# %%
metadata.head()
# Out:
#                        name  height  width  aspect_ratio  size resolution
# 0  199831878-10212369-0.png     128    128           1.0  8398    128x128
# 1  199813045-10212369-0.png     128    128           1.0  8025    128x128
# 2  199980236-10212369-0.png     128    128           1.0  9103    128x128
# 3  199784721-10212369-0.png     128    128           1.0  7497    128x128
# 4  199821586-10212369-0.png     128    128           1.0  9037    128x128

# %% [markdown]
# ### Images resolution

# %%
sns.countplot(data=metadata, x='resolution')
# Out:
# <Axes: xlabel='resolution', ylabel='count'>

# %% [markdown]
# - All the images have the exact same width and height.

# %% [markdown]
# ### Images Visualization

# %%
diaply_random_images(
    root=IMAGES_DIR,
    nrows=6,
    ncols=6,
)
