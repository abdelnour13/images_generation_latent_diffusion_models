# %% [markdown]
# ### Necessary Packages

# %%
import sys
import seaborn as sns
import warnings

# %%
sys.path.append('../..')

# %%
import definitions as D
from src.utils import get_metadata,diaply_random_images,get_metadata,seed_everything

# %%
warnings.filterwarnings("ignore",category=FutureWarning)
warnings.filterwarnings("ignore",category=UserWarning)

# %%
sns.set_theme(style="whitegrid", palette="Set2")

# %% [markdown]
# ### Reproducibility

# %%
SEED = 42
IMAGES_DIR = D.DATASETS['cartoon_faces'].images_dir

# %%
seed_everything(SEED)

# %% [markdown]
# ### Metadata

# %%
metadata = get_metadata(IMAGES_DIR)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
metadata.head()
# Out:
#                         name  height  width  aspect_ratio   size resolution
# 0  cs5871545700477675780.jpg     500    500           1.0  26390    500x500
# 1  cs9040986042232730481.jpg     500    500           1.0  29984    500x500
# 2  cs7003037474090021987.jpg     500    500           1.0  21445    500x500
# 3  cs4099648499814712267.jpg     500    500           1.0  33133    500x500
# 4  cs6338284098845504299.jpg     500    500           1.0  26905    500x500

# %% [markdown]
# ### Images resolution

# %%
sns.countplot(data=metadata, x='resolution')
# Out:
# <Axes: xlabel='resolution', ylabel='count'>

# %% [markdown]
# - All the images have the exact same width and height.

# %% [markdown]
# ### Images Visualization

# %%
diaply_random_images(
    root=IMAGES_DIR,
    nrows=6,
    ncols=6,
)
