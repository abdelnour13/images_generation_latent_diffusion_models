# %% [markdown]
# ### Necessary Packages

# %%
import sys
import seaborn as sns
import warnings

# %%
sys.path.append('..')

# %%
import definitions as D
from src.utils import get_metadata,diaply_random_images,get_metadata,seed_everything

# %%
warnings.filterwarnings("ignore",category=FutureWarning)
warnings.filterwarnings("ignore",category=UserWarning)

# %%
sns.set_theme(style="whitegrid", palette="Set2")

# %% [markdown]
# ### Reproducibility

# %%
SEED = 42
IMAGES_DIR = D.DATASETS['anime_faces'].images_dir

# %%
seed_everything(SEED)

# %% [markdown]
# ### Metadata

# %%
metadata = get_metadata(IMAGES_DIR)
# Out:
#   0%|          | 0/21551 [00:00<?, ?it/s]

# %%
metadata.head()
# Out:
#         name  height  width  aspect_ratio   size resolution
# 0   7781.png      64     64           1.0  10187      64x64
# 1   2540.png      64     64           1.0  10358      64x64
# 2  19854.png      64     64           1.0  10406      64x64
# 3   7139.png      64     64           1.0  11120      64x64
# 4   7801.png      64     64           1.0  10698      64x64

# %% [markdown]
# ### Images resolution

# %%
sns.countplot(data=metadata, x='resolution')
# Out:
# <Axes: xlabel='resolution', ylabel='count'>

# %% [markdown]
# - All the images have the exact same width and height.

# %% [markdown]
# ### Images Visualization

# %%
diaply_random_images(
    root=IMAGES_DIR,
    nrows=6,
    ncols=6,
)
